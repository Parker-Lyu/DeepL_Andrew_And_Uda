# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From D:\Software\Anaconda\envs\pyDL\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 1000 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 55.5083 0.4091 sec/batch
# Nearest to see: rangle, adjoint, early, beaked, dtt, classically, weaker, depositary,
# Nearest to and: vab, distance, petros, hijra, meisner, undifferentiated, british, dordrecht,
# Nearest to all: ruska, cardamom, centenary, quinlan, knockouts, spiked, familial, grim,
# Nearest to if: nomar, baracca, knights, bangalore, jumbo, surveyors, nonetheless, aaliyah,
# Nearest to most: affront, lpg, scylla, navy, tightness, emancipated, biot, raeben,
# Nearest to than: kaf, flanker, lewin, meeting, tinymush, prosecutions, sotho, habits,
# Nearest to war: tinctures, ascribe, haircut, degenerative, baudelaire, piccard, napoleon, ddc,
# Nearest to would: srp, amplifies, ran, ruston, tubular, nantes, constructing, regnum,
# Nearest to scale: formula, theorizes, modify, borders, mamre, hydrological, pennyworth, charts,
# Nearest to defense: kimsey, stafford, prognosis, featured, washburn, slowly, tukey, kathleen,
# Nearest to stage: troop, engelbert, baile, mimas, does, cdot, sent, viability,
# Nearest to freedom: egyptians, merges, pressing, undersecretary, monophysite, passing, casanova, destiny,
# Nearest to additional: pcb, denotes, sardo, ascalon, mahatma, masonry, jeanneret, charterhouse,
# Nearest to professional: puzo, toasts, rita, roaring, goshen, oxley, thoroughgoing, harriers,
# Nearest to woman: gutted, mummies, radioiodine, vig, moldavia, ectoplasm, prohibits, blythe,
# Nearest to square: jeannette, isp, consuming, flavoring, heretic, laps, signings, iss,
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 52.0531 0.4103 sec/batch
# Nearest to see: early, classically, rangle, adjoint, weaker, colours, along, tends,
# Nearest to and: distance, preferences, declined, depending, vab, petros, hijra, undifferentiated,
# Nearest to all: be, wars, centenary, shows, grim, independent, ruska, quinlan,
# Nearest to if: knights, forced, nonetheless, theologians, originate, vaux, jumbo, each,
# Nearest to most: affront, lpg, navy, events, versa, scylla, influential, reverse,
# Nearest to than: meeting, older, habits, encryption, modelled, barnabas, flanker, screenplay,
# Nearest to war: ascribe, tinctures, haircut, degenerative, historians, napoleon, baudelaire, ddc,
# Nearest to would: ran, perceive, constructing, srp, exploring, theme, probability, colon,
# Nearest to scale: formula, borders, modify, areas, june, teachers, charts, themselves,
# Nearest to defense: featured, kimsey, stafford, slowly, emulation, vangelis, washburn, tukey,
# Nearest to stage: does, troop, sent, engelbert, cdot, picked, taxation, baile,
# Nearest to freedom: egyptians, passing, pressing, via, inscription, landslide, jay, idaho,
# Nearest to additional: denotes, pcb, applies, discusses, army, masonry, ambition, chording,
# Nearest to professional: rita, puzo, jane, b, roaring, standards, weren, toasts,
# Nearest to woman: gutted, representatives, student, thousands, prohibits, vig, often, mummies,
# Nearest to square: consuming, isp, jeannette, heretic, flavoring, ratified, bosporus, laps,
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 48.4287 0.4083 sec/batch
# Nearest to see: adjoint, rangle, early, classically, weaker, snap, colours, tends,
# Nearest to and: distance, preferences, proposal, declined, vab, petros, brain, leibniz,
# Nearest to all: be, centenary, ruska, quinlan, wars, grim, cardamom, valid,
# Nearest to if: knights, nonetheless, formulas, baracca, processing, meaningful, commence, gratis,
# Nearest to most: affront, lpg, navy, reverse, events, scylla, proposing, attractive,
# Nearest to than: meeting, flanker, lewin, modelled, interchangeable, barnabas, prosecutions, older,
# Nearest to war: tinctures, haircut, ascribe, napoleon, degenerative, baudelaire, penrose, ratified,
# Nearest to would: ran, perceive, constructing, srp, probability, exploring, observer, colon,
# Nearest to scale: formula, borders, areas, modify, labs, theorizes, charts, june,
# Nearest to defense: featured, kimsey, stafford, emulation, fr, kathleen, vangelis, slowly,
# Nearest to stage: sent, does, troop, engelbert, cdot, pending, picked, assigns,
# Nearest to freedom: egyptians, landslide, passing, merges, inscription, via, jay, destiny,
# Nearest to additional: pcb, ambition, denotes, mahatma, masonry, ascalon, charterhouse, demonstrably,
# Nearest to professional: puzo, jane, roaring, weren, rita, standards, b, goshen,
# Nearest to woman: gutted, vig, representatives, student, thousands, prohibits, simplex, moldavia,
# Nearest to square: isp, consuming, heretic, flavoring, jeannette, ratified, bosporus, laps,
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 47.1200 0.4103 sec/batch
# Nearest to see: adjoint, rangle, early, classically, snap, weaker, mcpherson, colours,
# Nearest to and: vab, declined, petros, brain, leibniz, distance, proposal, preferences,
# Nearest to all: ruska, be, centenary, knockouts, quinlan, cardamom, correspondents, cebidae,
# Nearest to if: baracca, bangalore, nomar, commence, processing, meaningful, nonetheless, decryption,
# Nearest to most: affront, lpg, navy, scylla, framework, simultaneous, emancipated, brandon,
# Nearest to than: meeting, flanker, modelled, prosecutions, lewin, interchangeable, barnabas, kaf,
# Nearest to war: haircut, tinctures, napoleon, ascribe, baudelaire, military, exporting, ratified,
# Nearest to would: perceive, ran, srp, constructing, probability, exploring, brazil, amplifies,
# Nearest to scale: formula, borders, areas, modify, theorizes, labs, poseidon, themselves,
# Nearest to defense: featured, stafford, kimsey, kathleen, insurgency, slowly, emulation, washburn,
# Nearest to stage: sent, engelbert, troop, assigns, cdot, does, moynihan, baile,
# Nearest to freedom: egyptians, landslide, passing, undersecretary, destiny, jay, merges, via,
# Nearest to additional: pcb, ambition, mahatma, denotes, calibrated, demonstrably, ascalon, charterhouse,
# Nearest to professional: puzo, jane, b, rita, roaring, standards, weren, knobs,
# Nearest to woman: gutted, vig, thousands, student, mummies, representatives, prohibits, moldavia,
# Nearest to square: isp, consuming, jeannette, flavoring, bosporus, heretic, laps, notwithstanding,
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 45.9418 0.1508 sec/batch
# Nearest to see: adjoint, rangle, snap, early, classically, weaker, mcpherson, dtt,
# Nearest to and: leibniz, petros, vab, lottery, brain, declined, subsidised, preferences,
# Nearest to all: be, ruska, centenary, knockouts, quinlan, correspondents, cebidae, treblinka,
# Nearest to if: baracca, formulas, processing, nomar, values, bangalore, meaningful, vectors,
# Nearest to most: affront, lpg, navy, tightness, framework, ammonites, simultaneous, scylla,
# Nearest to than: flanker, meeting, interchangeable, prosecutions, lewin, modelled, cytoplasm, bases,
# Nearest to war: haircut, napoleon, tinctures, baudelaire, military, midianites, ratified, hercules,
# Nearest to would: perceive, ran, probability, intend, srp, constructing, warn, calculators,
# Nearest to scale: formula, areas, modify, theorizes, borders, pennyworth, labs, locked,
# Nearest to defense: featured, stafford, kimsey, insurgency, tukey, slowly, kathleen, emulation,
# Nearest to stage: sent, engelbert, troop, baile, cdot, does, spaceflight, assigns,
# Nearest to freedom: egyptians, landslide, destiny, undersecretary, passing, merges, gathering, via,
# Nearest to additional: pcb, ambition, calibrated, particularity, demonstrably, rummel, customer, denotes,
# Nearest to professional: puzo, b, jane, rita, roaring, standards, reinforce, singles,
# Nearest to woman: gutted, vig, student, moldavia, thousands, simplex, mummies, brig,
# Nearest to square: consuming, jeannette, isp, bosporus, flavoring, laps, heretic, disoriented,
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 44.7150 0.4069 sec/batch
# Nearest to see: adjoint, rangle, snap, early, dtt, classically, weaker, mcpherson,
# Nearest to and: distance, roadways, metalworking, wafer, roch, petros, leibniz, declined,
# Nearest to all: be, ruska, knockouts, valid, predisposition, cebidae, correspondents, centenary,
# Nearest to if: formulas, values, baracca, processing, nomar, processes, abelian, subspace,
# Nearest to most: affront, lpg, soaking, navy, framework, predation, realpolitik, tightness,
# Nearest to than: flanker, interchangeable, meeting, lewin, symmetric, prosecutions, bases, asynchronous,
# Nearest to war: military, midianites, napoleon, baudelaire, haircut, tinctures, ratified, hercules,
# Nearest to would: ran, probability, perceive, intend, bidder, individually, decks, constructing,
# Nearest to scale: formula, areas, modify, labs, theorizes, tls, resize, borders,
# Nearest to defense: insurgency, kimsey, tukey, slowly, featured, stafford, kathleen, picot,
# Nearest to stage: engelbert, sent, naught, troop, spaceflight, cdot, baile, assigns,
# Nearest to freedom: egyptians, landslide, undersecretary, eccentricity, gathering, via, traction, passing,
# Nearest to additional: pcb, ambition, calibrated, demonstrably, customer, aspirated, rummel, particularity,
# Nearest to professional: puzo, jane, b, singles, roaring, reinforce, unscr, rita,
# Nearest to woman: gutted, vig, student, blythe, moldavia, mummies, thousands, simplex,
# Nearest to square: jeannette, bosporus, consuming, flavoring, miles, isp, sq, densely,
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 44.1702 0.4079 sec/batch
# Nearest to see: adjoint, rangle, dtt, snap, early, classically, colours, restarting,
# Nearest to and: petros, hijra, preferences, declined, wafer, hesitant, roadways, leibniz,
# Nearest to all: be, ruska, valid, knockouts, predisposition, correspondents, grip, fertilize,
# Nearest to if: baracca, nomar, formulas, values, vectors, donuts, processing, decryption,
# Nearest to most: affront, lpg, simultaneous, emancipated, ammonites, predation, realpolitik, soaking,
# Nearest to than: flanker, meeting, bases, lewin, rattlesnake, symmetric, interchangeable, dehydrated,
# Nearest to war: midianites, military, napoleon, baudelaire, haircut, tinctures, ratified, bloomberg,
# Nearest to would: ran, perceive, individually, probability, intend, warn, bidder, manoeuvres,
# Nearest to scale: areas, formula, theorizes, modify, labs, tls, pennyworth, locked,
# Nearest to defense: insurgency, slowly, kimsey, tukey, kathleen, featured, stafford, picot,
# Nearest to stage: engelbert, assigns, sent, picked, naught, spaceflight, troop, baile,
# Nearest to freedom: landslide, egyptians, gathering, undersecretary, eccentricity, monophysite, frud, via,
# Nearest to additional: calibrated, pcb, ambition, rummel, particularity, aspirated, demonstrably, customer,
# Nearest to professional: puzo, singles, b, unscr, roaring, jane, standards, aggravating,
# Nearest to woman: vig, gutted, student, blythe, moldavia, supper, thousands, dea,
# Nearest to square: bosporus, jeannette, consuming, miles, haddock, isp, flavoring, sq,
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 43.6753 0.4042 sec/batch
# Nearest to see: adjoint, rangle, snap, classically, early, dtt, mcdonald, history,
# Nearest to and: declined, hesitant, preferences, petros, wafer, roadways, proposal, choreographies,
# Nearest to all: be, ruska, valid, knockouts, predisposition, treblinka, raised, grip,
# Nearest to if: baracca, nomar, donuts, values, vectors, formulas, subspace, decryption,
# Nearest to most: affront, lpg, simultaneous, predation, emancipated, ammonites, realpolitik, framework,
# Nearest to than: flanker, bases, rattlesnake, meeting, interchangeable, classifications, prosecutions, johanson,
# Nearest to war: military, midianites, napoleon, ratified, baudelaire, saw, haircut, occupation,
# Nearest to would: ran, intend, perceive, individually, probability, bidder, injure, warn,
# Nearest to scale: areas, formula, hydrological, labs, borders, pennyworth, tls, theorizes,
# Nearest to defense: insurgency, slowly, picot, tukey, kimsey, bailed, kathleen, recantation,
# Nearest to stage: engelbert, assigns, sent, naught, picked, mimas, spaceflight, curbed,
# Nearest to freedom: landslide, gathering, egyptians, undersecretary, frud, monophysite, eccentricity, via,
# Nearest to additional: pcb, calibrated, ambition, rummel, particularity, aspirated, unaided, demonstrably,
# Nearest to professional: puzo, singles, standards, aggravating, jane, goshen, reedy, unscr,
# Nearest to woman: vig, student, gutted, blythe, supper, dubois, darwinists, dea,
# Nearest to square: bosporus, jeannette, sq, miles, densely, isp, consuming, haddock,
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 43.1849 0.4118 sec/batch
# Nearest to see: adjoint, dtt, rangle, snap, restarting, classically, defined, history,
# Nearest to and: hesitant, petros, preferences, declined, gottlob, pmrc, choreographies, leibniz,
# Nearest to all: be, ruska, valid, knockouts, treblinka, centenary, raised, grip,
# Nearest to if: baracca, vectors, nomar, subspace, values, donuts, that, defined,
# Nearest to most: affront, lpg, simultaneous, predation, realpolitik, ammonites, emancipated, wholly,
# Nearest to than: flanker, rattlesnake, meeting, bases, prosecutions, johanson, lewin, tinymush,
# Nearest to war: midianites, military, napoleon, baudelaire, haircut, ratified, tinctures, saw,
# Nearest to would: intend, perceive, bidder, ran, probability, individually, decks, injure,
# Nearest to scale: formula, tls, pennyworth, areas, hydrological, theorizes, borders, resize,
# Nearest to defense: insurgency, slowly, picot, tukey, kimsey, rebuild, recantation, bailed,
# Nearest to stage: engelbert, naught, picked, remember, mimas, baile, comic, toured,
# Nearest to freedom: landslide, gathering, frud, monophysite, undersecretary, egyptians, clannad, eccentricity,
# Nearest to additional: calibrated, rummel, pcb, ambition, particularity, aspirated, unaided, denotes,
# Nearest to professional: puzo, singles, jane, goshen, b, roaring, sukkah, university,
# Nearest to woman: vig, supper, gutted, student, dubois, blythe, darwinists, astbury,
# Nearest to square: bosporus, jeannette, sq, miles, densely, isp, tributary, haddock,
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 42.4871 0.3026 sec/batch
# Nearest to see: adjoint, dtt, history, rangle, restarting, snap, classically, mcpherson,
# Nearest to and: hesitant, preferences, cohesion, choreographies, discharged, declined, roadways, decibel,
# Nearest to all: be, valid, ruska, knockouts, raised, predisposition, inequality, treblinka,
# Nearest to if: nomar, baracca, donuts, subspace, vectors, values, aaliyah, forced,
# Nearest to most: affront, lpg, simultaneous, ammonites, emancipated, enclaves, predation, realpolitik,
# Nearest to than: flanker, bases, meeting, rattlesnake, prosecutions, classifications, tinymush, lewin,
# Nearest to war: midianites, military, ratified, napoleon, baudelaire, haircut, tinctures, saw,
# Nearest to would: bidder, ran, intend, decks, perceive, probability, individually, warn,
# Nearest to scale: pennyworth, formula, tls, areas, borders, labs, toy, overall,
# Nearest to defense: insurgency, slowly, picot, tukey, kimsey, telemark, recantation, bailed,
# Nearest to stage: naught, engelbert, baile, maintainability, picked, mimas, remember, toured,
# Nearest to freedom: landslide, gathering, clannad, eccentricity, undersecretary, monophysite, via, traction,
# Nearest to additional: calibrated, rummel, pcb, ambition, prime, aspirated, customer, particularity,
# Nearest to professional: puzo, singles, standards, jane, goshen, aggravating, sukkah, unscr,
# Nearest to woman: vig, supper, student, gutted, inhaled, omnivores, blythe, darwinists,
# Nearest to square: bosporus, sq, peninsulas, miles, tributary, densely, jeannette, area,
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 41.9332 0.4061 sec/batch
# Nearest to see: adjoint, dtt, rangle, defined, history, pretentious, glossary, snap,
# Nearest to and: hesitant, metalworking, cohesion, wafer, preferences, choreographies, queue, leibniz,
# Nearest to all: be, valid, ruska, this, knockouts, predisposition, raised, fertilize,
# Nearest to if: subspace, baracca, nomar, vectors, donuts, values, same, formulas,
# Nearest to most: affront, lpg, simultaneous, ammonites, realpolitik, predation, emancipated, tightness,
# Nearest to than: flanker, rattlesnake, bases, meeting, eyeball, prosecutions, tinymush, classifications,
# Nearest to war: midianites, military, napoleon, baudelaire, ratified, haircut, hercules, naval,
# Nearest to would: ran, intend, decks, bidder, probability, perceive, individually, warn,
# Nearest to scale: tls, formula, toy, areas, pennyworth, borders, decades, akshara,
# Nearest to defense: insurgency, picot, slowly, tukey, kimsey, featured, volante, kathleen,
# Nearest to stage: naught, maintainability, engelbert, baile, success, assigns, jubilee, mosfet,
# Nearest to freedom: landslide, gathering, clannad, traction, monophysite, undersecretary, eccentricity, frud,
# Nearest to additional: pcb, calibrated, rummel, prime, ambition, customer, obtainable, aspirated,
# Nearest to professional: singles, puzo, aggravating, departments, standards, goshen, unscr, lyc,
# Nearest to woman: vig, supper, omnivores, prevalence, darwinists, student, inhaled, gutted,
# Nearest to square: bosporus, sq, peninsulas, road, miles, cidade, jeannette, weu,
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 41.7977 0.4095 sec/batch
# Nearest to see: adjoint, dtt, defined, history, glossary, rangle, snap, restarting,
# Nearest to and: hesitant, wafer, choreographies, brain, gottlob, metalworking, preferences, napoleonic,
# Nearest to all: be, valid, ruska, raised, fertilize, inequality, predisposition, this,
# Nearest to if: nomar, baracca, donuts, subspace, vectors, eyepiece, aaliyah, values,
# Nearest to most: affront, lpg, edd, emancipated, simultaneous, predation, many, ammonites,
# Nearest to than: flanker, rattlesnake, bases, meeting, classifications, jeux, lewin, eyeball,
# Nearest to war: midianites, military, napoleon, ratified, naval, baudelaire, regiment, haircut,
# Nearest to would: ran, intend, probability, bidder, individually, perceive, decks, manoeuvres,
# Nearest to scale: tls, decades, borders, akshara, areas, toy, pennyworth, formula,
# Nearest to defense: insurgency, picot, slowly, kimsey, tukey, assailants, volante, bailed,
# Nearest to stage: maintainability, naught, engelbert, mosfet, jubilee, virtues, assigns, mimas,
# Nearest to freedom: landslide, gathering, clannad, flynn, undersecretary, traction, eccentricity, entangled,
# Nearest to additional: calibrated, prime, pcb, rummel, ambition, customer, aspirated, chording,
# Nearest to professional: singles, departments, aggravating, puzo, standards, goshen, sukkah, unscr,
# Nearest to woman: vig, supper, prevalence, darwinists, inhaled, omnivores, gutted, sportscaster,
# Nearest to square: bosporus, isp, sq, haddock, peninsulas, crossbows, road, weu,
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 41.7105 0.4192 sec/batch
# Nearest to see: adjoint, history, dtt, glossary, authoritative, defined, cundinamarca, communications,
# Nearest to and: hesitant, choreographies, gottlob, monotheism, declined, was, napoleonic, brain,
# Nearest to all: be, valid, ruska, raised, unbelief, plo, armenia, nadir,
# Nearest to if: subspace, nomar, vectors, eyepiece, donuts, baracca, aaliyah, values,
# Nearest to most: affront, many, lpg, ammonites, emancipated, wholly, abortive, simultaneous,
# Nearest to than: flanker, rattlesnake, bases, meeting, cossack, mightiest, eyeball, older,
# Nearest to war: midianites, military, napoleon, ratified, propaganda, regiment, baudelaire, occupation,
# Nearest to would: ran, intend, negotiations, individually, dayan, manoeuvres, hate, deterred,
# Nearest to scale: toy, borders, akshara, tls, overall, pennyworth, decades, presaged,
# Nearest to defense: picot, insurgency, slowly, tukey, kathleen, kimsey, assailants, volante,
# Nearest to stage: maintainability, engelbert, virtues, jubilee, naught, depardieu, moynihan, silverdome,
# Nearest to freedom: landslide, gathering, clannad, undersecretary, flynn, via, frud, traction,
# Nearest to additional: calibrated, rummel, pcb, prime, ambition, sardo, customer, bovril,
# Nearest to professional: puzo, singles, departments, jane, goshen, lyc, aggravating, sukkah,
# Nearest to woman: vig, supper, prevalence, inhaled, astbury, omnivores, birth, darwinists,
# Nearest to square: bosporus, sq, isp, peninsulas, weu, crossbows, haddock, cidade,
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 41.4358 0.0502 sec/batch
# Nearest to see: adjoint, history, rangle, dtt, glossary, communications, defined, cundinamarca,
# Nearest to and: hesitant, choreographies, gottlob, factor, mythography, preferences, kush, declined,
# Nearest to all: be, valid, ruska, predisposition, strumming, inequality, plo, knockouts,
# Nearest to if: nomar, subspace, donuts, eyepiece, vectors, baracca, aaliyah, forced,
# Nearest to most: affront, many, ammonites, emancipated, lpg, edd, wholly, simultaneous,
# Nearest to than: flanker, rattlesnake, bases, meeting, mightiest, cossack, contribute, older,
# Nearest to war: midianites, military, propaganda, regiment, ratified, napoleon, baudelaire, boris,
# Nearest to would: ran, intend, probability, bidder, decks, negotiations, individually, manoeuvres,
# Nearest to scale: borders, overall, toy, decades, akshara, pennyworth, flattening, presaged,
# Nearest to defense: picot, tukey, insurgency, slowly, kathleen, featured, assailants, volante,
# Nearest to stage: maintainability, virtues, jubilee, naught, engelbert, moynihan, silverdome, depardieu,
# Nearest to freedom: landslide, clannad, undersecretary, gathering, flynn, traction, monophysite, frud,
# Nearest to additional: calibrated, rummel, pcb, prime, ambition, customer, obtainable, chording,
# Nearest to professional: singles, departments, puzo, goshen, jane, standards, aggravating, sukkah,
# Nearest to woman: prevalence, vig, supper, birth, female, inhaled, astbury, omnivores,
# Nearest to square: bosporus, peninsulas, sq, crossbows, isp, weu, haddock, metres,
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 40.7755 0.4078 sec/batch
# Nearest to see: adjoint, glossary, cundinamarca, history, communications, dtt, rangle, pretentious,
# Nearest to and: hesitant, kush, factor, choreographies, metalworking, meandering, chadic, nintendo,
# Nearest to all: be, valid, this, ruska, neglects, replicates, does, predisposition,
# Nearest to if: nomar, donuts, eyepiece, vectors, subspace, baracca, you, aaliyah,
# Nearest to most: affront, many, edd, ammonites, lpg, emancipated, cutscenes, enclaves,
# Nearest to than: flanker, bases, rattlesnake, mightiest, meeting, older, symmetric, interchangeable,
# Nearest to war: midianites, military, propaganda, naval, regiment, forces, ratified, hercules,
# Nearest to would: intend, ran, decks, negotiations, bidder, individually, probability, deterred,
# Nearest to scale: borders, toy, akshara, overall, stable, presaged, methodology, capitalist,
# Nearest to defense: picot, tukey, insurgency, slowly, featured, kathleen, assailants, bailed,
# Nearest to stage: maintainability, mosfet, naught, virtues, jubilee, viability, amphitheatre, engelbert,
# Nearest to freedom: landslide, clannad, undersecretary, traction, gathering, flynn, entangled, via,
# Nearest to additional: calibrated, pcb, rummel, prime, chording, unaided, sardo, customer,
# Nearest to professional: departments, singles, puzo, lyc, majors, unscr, sports, goshen,
# Nearest to woman: prevalence, vig, supper, female, astbury, inhaled, hiv, omnivores,
# Nearest to square: bosporus, sq, peninsulas, road, weu, cidade, metres, crossbows,
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 40.6417 0.4118 sec/batch
# Nearest to see: adjoint, glossary, cundinamarca, dtt, rangle, history, concordance, globalsecurity,
# Nearest to and: monotheism, hesitant, choreographies, gottlob, chadic, preferences, in, kush,
# Nearest to all: be, valid, ruska, this, replicates, predisposition, does, wednesday,
# Nearest to if: subspace, vectors, nomar, eyepiece, baracca, donuts, divisor, f,
# Nearest to most: affront, many, edd, lpg, cutscenes, variants, enclaves, emancipated,
# Nearest to than: flanker, rattlesnake, bases, meeting, symmetric, mightiest, xxxxx, kaf,
# Nearest to war: midianites, military, propaganda, naval, vacancies, regiment, hercules, lai,
# Nearest to would: ran, intend, probability, individually, negotiations, scoreless, deterred, makkah,
# Nearest to scale: underemployed, akshara, methodology, borders, stable, hawking, decades, presaged,
# Nearest to defense: picot, tukey, insurgency, assailants, kathleen, featured, slowly, volante,
# Nearest to stage: maintainability, mosfet, virtues, engelbert, silverdome, naught, amphitheatre, moynihan,
# Nearest to freedom: landslide, clannad, undersecretary, gathering, entangled, traction, flynn, via,
# Nearest to additional: pcb, calibrated, rummel, prime, chording, ambition, customer, unaided,
# Nearest to professional: departments, aggravating, organization, mahuad, lyc, unscr, classroom, university,
# Nearest to woman: vig, prevalence, female, supper, birth, astbury, omnivores, sex,
# Nearest to square: bosporus, peninsulas, sq, cidade, weu, isp, road, haddock,
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 40.6749 0.4117 sec/batch
# Nearest to see: cundinamarca, adjoint, history, glossary, globalsecurity, communications, dtt, protoscience,
# Nearest to and: monotheism, hesitant, choreographies, the, kush, gottlob, in, cohesion,
# Nearest to all: be, valid, armenia, ruska, does, plo, this, quinlan,
# Nearest to if: subspace, nomar, vectors, eyepiece, aaliyah, donuts, baracca, you,
# Nearest to most: many, affront, edd, nobi, emancipated, lpg, enclaves, variants,
# Nearest to than: flanker, rattlesnake, bases, mightiest, figure, cossack, unpredictably, dehydrated,
# Nearest to war: midianites, propaganda, military, napoleon, nazi, vacancies, naval, ratified,
# Nearest to would: ran, intend, scoreless, negotiations, rko, forefather, probability, individually,
# Nearest to scale: borders, underemployed, akshara, methodology, stable, devote, decades, hawking,
# Nearest to defense: picot, tukey, insurgency, kathleen, assailants, featured, kimsey, slowly,
# Nearest to stage: maintainability, amphitheatre, virtues, mosfet, engelbert, silverdome, jubilee, assigns,
# Nearest to freedom: landslide, clannad, undersecretary, gathering, jutsu, entangled, via, opposed,
# Nearest to additional: calibrated, rummel, pcb, prime, chording, sardo, customer, bovril,
# Nearest to professional: departments, aggravating, organization, mahuad, majors, lyc, sukkah, sports,
# Nearest to woman: vig, female, prevalence, inhaled, birth, hiv, astbury, less,
# Nearest to square: bosporus, peninsulas, sq, isp, weu, cidade, crossbows, road,
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 40.6229 0.4092 sec/batch
# Nearest to see: cundinamarca, adjoint, glossary, communications, history, globalsecurity, concordance, protoscience,
# Nearest to and: cohesion, the, monotheism, hesitant, gottlob, in, metalworking, burst,
# Nearest to all: be, valid, armenia, ruska, does, quinlan, replicates, satisfies,
# Nearest to if: vectors, subspace, nomar, aaliyah, eyepiece, f, donuts, divisor,
# Nearest to most: many, affront, edd, enclaves, reenactment, emancipated, nobi, variants,
# Nearest to than: flanker, mightiest, rattlesnake, bases, older, homozygote, xxxxx, least,
# Nearest to war: midianites, vacancies, propaganda, military, nazi, wounded, ratified, naval,
# Nearest to would: ran, intend, negotiations, probability, deterred, individually, makkah, endorse,
# Nearest to scale: methodology, underemployed, borders, akshara, devote, flattening, hawking, stable,
# Nearest to defense: picot, tukey, insurgency, assailants, slowly, kathleen, peacekeeping, kimsey,
# Nearest to stage: maintainability, silverdome, virtues, engelbert, amphitheatre, jubilee, success, mosfet,
# Nearest to freedom: landslide, clannad, undersecretary, gathering, jutsu, entangled, flynn, sel,
# Nearest to additional: calibrated, rummel, pcb, chording, saari, prime, customer, bovril,
# Nearest to professional: departments, majors, lyc, weigel, puzo, sports, mahuad, jane,
# Nearest to woman: female, vig, prevalence, birth, astbury, inhaled, hiv, nationality,
# Nearest to square: bosporus, sq, peninsulas, jacobian, crossbows, isp, weu, cidade,
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 40.2240 0.2040 sec/batch
# Nearest to see: cundinamarca, adjoint, concordance, glossary, globalsecurity, history, protoscience, rangle,
# Nearest to and: monotheism, the, cohesion, in, burst, mythography, choreographies, was,
# Nearest to all: be, valid, armenia, ruska, does, wednesday, replicates, ambrosians,
# Nearest to if: vectors, subspace, nomar, aaliyah, f, eyepiece, donuts, values,
# Nearest to most: many, affront, bodied, variants, edd, somewhat, emancipated, simultaneous,
# Nearest to than: flanker, mightiest, bases, least, rattlesnake, meeting, xxxxx, older,
# Nearest to war: midianites, vacancies, wounded, propaganda, naval, military, ratified, nazi,
# Nearest to would: ran, negotiations, intend, endorse, makkah, individually, finally, deterred,
# Nearest to scale: underemployed, methodology, devote, akshara, stable, borders, flattening, imperceptible,
# Nearest to defense: tukey, picot, assailants, insurgency, slowly, osi, cdg, peacekeeping,
# Nearest to stage: maintainability, silverdome, mosfet, virtues, amphitheatre, engelbert, discomfort, hydration,
# Nearest to freedom: landslide, undersecretary, clannad, jutsu, gathering, entangled, eccentricity, opposed,
# Nearest to additional: calibrated, pcb, rummel, chording, customer, saari, unaided, bovril,
# Nearest to professional: departments, majors, lyc, sports, weigel, mahuad, organization, singles,
# Nearest to woman: female, prevalence, vig, birth, hiv, inhaled, astbury, nationality,
# Nearest to square: bosporus, sq, peninsulas, area, crossbows, weu, jacobian, isp,
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 39.7935 0.4095 sec/batch
# Nearest to see: cundinamarca, adjoint, concordance, globalsecurity, glossary, rangle, communications, history,
# Nearest to and: the, in, monotheism, cohesion, generalised, etching, meandering, gaspard,
# Nearest to all: be, valid, replicates, satisfies, does, see, armenia, neglects,
# Nearest to if: vectors, subspace, aaliyah, nomar, eyepiece, f, divisor, values,
# Nearest to most: many, affront, edd, bodied, sets, variants, enclaves, somewhat,
# Nearest to than: flanker, bases, least, mightiest, xxxxx, rattlesnake, older, circ,
# Nearest to war: vacancies, propaganda, midianites, naval, wounded, military, harrier, hercules,
# Nearest to would: ran, negotiations, deterred, finally, makkah, intend, endorse, allowed,
# Nearest to scale: devote, underemployed, methodology, borders, hawking, akshara, presaged, antisemitism,
# Nearest to defense: tukey, picot, assailants, cdg, peacekeeping, polaris, osi, featured,
# Nearest to stage: maintainability, virtues, silverdome, amphitheatre, engelbert, mosfet, uefa, success,
# Nearest to freedom: landslide, undersecretary, clannad, jutsu, entangled, eccentricity, sel, gathering,
# Nearest to additional: calibrated, pcb, chording, rummel, unaided, prime, saari, sardo,
# Nearest to professional: departments, majors, mahuad, lyc, sports, unscr, organization, classroom,
# Nearest to woman: female, prevalence, hiv, vig, birth, inhaled, astbury, nationality,
# Nearest to square: bosporus, peninsulas, sq, area, cidade, weu, road, jacobian,
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 39.9373 0.4155 sec/batch
# Nearest to see: cundinamarca, adjoint, globalsecurity, all, terrier, concordance, glossary, communications,
# Nearest to and: in, the, monotheism, also, for, gaspard, gottlob, etching,
# Nearest to all: be, valid, see, satisfies, does, armenia, replicates, ruska,
# Nearest to if: aaliyah, vectors, nomar, subspace, eyepiece, donuts, decryption, divisor,
# Nearest to most: many, affront, edd, bodied, enclaves, sets, variants, somewhat,
# Nearest to than: flanker, bases, mightiest, xxxxx, least, rattlesnake, older, symmetric,
# Nearest to war: midianites, vacancies, propaganda, naval, wounded, lai, airlift, nazi,
# Nearest to would: ran, intend, negotiations, makkah, endorse, deciding, deterred, individually,
# Nearest to scale: devote, underemployed, methodology, borders, akshara, hawking, stable, flattening,
# Nearest to defense: tukey, picot, assailants, cdg, polaris, volante, kathleen, featured,
# Nearest to stage: maintainability, virtues, mosfet, silverdome, amphitheatre, engelbert, uefa, latitude,
# Nearest to freedom: landslide, undersecretary, clannad, jutsu, entangled, gathering, eccentricity, opposed,
# Nearest to additional: calibrated, chording, pcb, unaided, saari, rummel, prime, customer,
# Nearest to professional: departments, majors, sports, classroom, mahuad, lyc, unscr, organization,
# Nearest to woman: vig, birth, female, hiv, prevalence, inhaled, astbury, nationality,
# Nearest to square: bosporus, peninsulas, sq, segment, basler, cidade, road, weu,
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 39.9045 0.4192 sec/batch
# Nearest to see: cundinamarca, globalsecurity, history, communications, all, topics, adjoint, glossary,
# Nearest to and: the, in, for, cohesion, monotheism, with, enrolled, faced,
# Nearest to all: be, see, valid, armenia, satisfies, does, frisian, ruska,
# Nearest to if: vectors, aaliyah, subspace, eyepiece, nomar, donuts, decryption, multiplied,
# Nearest to most: many, affront, variants, enclaves, edd, bodied, somewhat, emancipated,
# Nearest to than: flanker, bases, least, mightiest, rattlesnake, homozygote, older, xxxxx,
# Nearest to war: propaganda, midianites, vacancies, nazi, naval, airlift, reich, ratified,
# Nearest to would: ran, negotiations, finally, intend, zamenhof, deciding, makkah, individually,
# Nearest to scale: underemployed, devote, methodology, borders, hawking, akshara, flattening, ago,
# Nearest to defense: tukey, picot, assailants, peacekeeping, cdg, polaris, kimsey, recantation,
# Nearest to stage: maintainability, virtues, amphitheatre, engelbert, silverdome, mosfet, uefa, latitude,
# Nearest to freedom: landslide, undersecretary, jutsu, clannad, gathering, communitarian, entangled, opposed,
# Nearest to additional: calibrated, chording, pcb, rummel, saari, unaided, customer, bovril,
# Nearest to professional: departments, majors, sports, sukkah, lyc, classroom, mahuad, organization,
# Nearest to woman: birth, female, vig, prevalence, inhaled, hiv, nationality, less,
# Nearest to square: bosporus, peninsulas, sq, segment, cidade, stadt, weu, jacobian,
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 39.7904 0.4145 sec/batch
# Nearest to see: cundinamarca, all, globalsecurity, history, communications, concordance, topics, glossary,
# Nearest to and: the, in, also, with, mainframe, for, other, cohesion,
# Nearest to all: be, see, armenia, satisfies, valid, does, in, replicates,
# Nearest to if: vectors, aaliyah, subspace, f, nomar, multiplied, denoted, eyepiece,
# Nearest to most: many, enclaves, affront, variants, bodied, exotic, sets, edd,
# Nearest to than: flanker, mightiest, bases, least, homozygote, older, rattlesnake, high,
# Nearest to war: vacancies, propaganda, revisionist, midianites, wounded, naval, reich, dyess,
# Nearest to would: ran, negotiations, finally, zamenhof, majorities, makkah, deciding, endorse,
# Nearest to scale: underemployed, methodology, borders, ago, devote, flattening, akshara, hawking,
# Nearest to defense: tukey, picot, cdg, assailants, peacekeeping, halakhah, osi, insurgency,
# Nearest to stage: maintainability, silverdome, virtues, engelbert, amphitheatre, uefa, performances, mosfet,
# Nearest to freedom: landslide, undersecretary, clannad, jutsu, sel, laissez, communitarian, entangled,
# Nearest to additional: calibrated, chording, pcb, unaided, rummel, saari, customer, denotes,
# Nearest to professional: departments, majors, lyc, sukkah, standards, unscr, organization, classroom,
# Nearest to woman: female, prevalence, birth, nationality, hiv, fertility, vig, inhaled,
# Nearest to square: bosporus, peninsulas, sq, segment, oblique, stadt, area, jacobian,
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 39.5549 0.3569 sec/batch
# Nearest to see: cundinamarca, globalsecurity, all, glossary, history, concordance, communications, adjoint,
# Nearest to and: the, in, also, monotheism, by, for, cohesion, was,
# Nearest to all: be, see, satisfies, armenia, in, does, valid, essendon,
# Nearest to if: vectors, aaliyah, nomar, denoted, multiplied, taz, surveyors, f,
# Nearest to most: many, bodied, sets, major, edd, affront, variants, enclaves,
# Nearest to than: flanker, bases, least, mightiest, homozygote, rattlesnake, unpredictably, more,
# Nearest to war: vacancies, propaganda, wounded, shrapnel, naval, revisionist, midianites, nazi,
# Nearest to would: finally, ran, makkah, rko, zamenhof, deterred, negotiations, intend,
# Nearest to scale: underemployed, methodology, devote, borders, flattening, ago, imperceptible, hawking,
# Nearest to defense: tukey, picot, cdg, featured, backs, assailants, passer, polaris,
# Nearest to stage: maintainability, virtues, silverdome, amphitheatre, fusing, spaceflight, mosfet, engelbert,
# Nearest to freedom: landslide, undersecretary, clannad, jutsu, sel, eccentricity, vows, communitarian,
# Nearest to additional: calibrated, chording, unaided, rummel, pcb, saari, elixir, customer,
# Nearest to professional: departments, majors, sports, unscr, football, mahuad, lyc, players,
# Nearest to woman: female, nationality, vig, hiv, inhaled, prevalence, birth, less,
# Nearest to square: bosporus, peninsulas, sq, moldovans, segment, stadt, provost, oblique,
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 39.2373 0.4122 sec/batch
# Nearest to see: cundinamarca, concordance, globalsecurity, all, adjoint, glossary, terrier, topics,
# Nearest to and: the, in, also, for, by, a, monotheism, with,
# Nearest to all: be, see, in, satisfies, armenia, are, this, valid,
# Nearest to if: vectors, aaliyah, nomar, subspace, denoted, f, treenode, multiplied,
# Nearest to most: many, bodied, sets, each, exotic, major, enclaves, somewhat,
# Nearest to than: flanker, least, mightiest, xxxxx, bases, homozygote, older, more,
# Nearest to war: vacancies, propaganda, naval, wounded, revisionist, dips, shrapnel, midianites,
# Nearest to would: ran, finally, makkah, zamenhof, deciding, negotiations, endorse, deterred,
# Nearest to scale: devote, underemployed, methodology, flattening, hawking, imperceptible, borders, ago,
# Nearest to defense: tukey, picot, cdg, featured, backs, passer, escorts, assailants,
# Nearest to stage: maintainability, silverdome, virtues, amphitheatre, clapping, mosfet, latitude, engelbert,
# Nearest to freedom: landslide, undersecretary, laissez, jutsu, clannad, communitarian, sel, opposed,
# Nearest to additional: chording, calibrated, unaided, pcb, elixir, on, customer, rummel,
# Nearest to professional: departments, majors, unscr, mahuad, lyc, organization, sports, sukkah,
# Nearest to woman: female, nationality, vig, hiv, inhaled, birth, prevalence, fertility,
# Nearest to square: bosporus, sq, peninsulas, segment, provost, oblique, area, moldovans,
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 39.4978 0.4113 sec/batch
# Nearest to see: all, cundinamarca, globalsecurity, concordance, topics, history, communications, terrier,
# Nearest to and: the, in, also, of, for, by, with, monotheism,
# Nearest to all: be, see, armenia, in, are, satisfies, essendon, does,
# Nearest to if: aaliyah, vectors, nomar, denoted, subspace, surveyors, f, treenode,
# Nearest to most: many, bodied, each, somewhat, edd, exotic, major, enclaves,
# Nearest to than: flanker, mightiest, least, bases, unpredictably, rattlesnake, more, xxxxx,
# Nearest to war: vacancies, revisionist, propaganda, nazi, naval, reich, wounded, midianites,
# Nearest to would: ran, finally, makkah, zamenhof, negotiations, rko, majorities, gully,
# Nearest to scale: underemployed, devote, flattening, methodology, ago, imperceptible, tempered, borders,
# Nearest to defense: tukey, picot, cdg, assailants, featured, backs, flathead, escorts,
# Nearest to stage: virtues, maintainability, amphitheatre, silverdome, mosfet, latitude, engelbert, hollow,
# Nearest to freedom: undersecretary, landslide, jutsu, clannad, laissez, communitarian, entangled, vows,
# Nearest to additional: calibrated, chording, unaided, rummel, customer, elixir, sardo, saari,
# Nearest to professional: majors, departments, unscr, sukkah, lyc, organization, sports, mahuad,
# Nearest to woman: vig, female, nationality, birth, hiv, less, inhaled, prevalence,
# Nearest to square: bosporus, sq, segment, peninsulas, provost, oblique, isp, jacobian,
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 39.5348 0.4082 sec/batch
# Nearest to see: all, cundinamarca, concordance, globalsecurity, topics, communications, history, external,
# Nearest to and: the, in, of, also, for, with, by, monotheism,
# Nearest to all: be, see, armenia, in, are, satisfies, scsi, does,
# Nearest to if: aaliyah, nomar, denoted, vectors, surveyors, treenode, taz, f,
# Nearest to most: many, in, bodied, cutscenes, major, edd, enclaves, affront,
# Nearest to than: mightiest, homozygote, least, flanker, more, bases, older, xxxxx,
# Nearest to war: vacancies, wounded, propaganda, revisionist, ratified, nazi, sanctified, midianites,
# Nearest to would: ran, finally, makkah, zamenhof, negotiations, continuance, gully, endorse,
# Nearest to scale: underemployed, devote, flattening, tempered, methodology, ago, borders, imperceptible,
# Nearest to defense: tukey, picot, cdg, halakhah, assailants, peacekeeping, featured, flathead,
# Nearest to stage: maintainability, virtues, amphitheatre, starred, silverdome, uefa, engelbert, performances,
# Nearest to freedom: undersecretary, landslide, jutsu, clannad, laissez, vows, opposed, communitarian,
# Nearest to additional: calibrated, chording, rummel, unaided, elixir, saari, sardo, customer,
# Nearest to professional: majors, departments, sukkah, unscr, organization, weigel, lyc, sports,
# Nearest to woman: vig, nationality, female, less, inhaled, hiv, birth, prevalence,
# Nearest to square: bosporus, sq, segment, peninsulas, provost, moldovans, stadt, oblique,
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 39.2454 0.0982 sec/batch
# Nearest to see: all, cundinamarca, topics, concordance, globalsecurity, related, communications, history,
# Nearest to and: the, in, also, of, monotheism, by, with, other,
# Nearest to all: be, see, armenia, in, satisfies, essendon, scsi, ambrosians,
# Nearest to if: nomar, aaliyah, surveyors, vectors, denoted, f, treenode, taz,
# Nearest to most: many, major, in, bodied, exotic, enclaves, affront, somewhat,
# Nearest to than: homozygote, least, mightiest, flanker, more, rather, unpredictably, bases,
# Nearest to war: vacancies, wounded, revisionist, propaganda, ratified, midianites, reich, calonne,
# Nearest to would: finally, ran, gully, negotiations, continuance, deterred, makkah, zamenhof,
# Nearest to scale: tempered, flattening, underemployed, devote, slabs, measuring, twelfth, imperceptible,
# Nearest to defense: tukey, cdg, backs, picot, goal, halakhah, assailants, tularemia,
# Nearest to stage: maintainability, virtues, latitude, amphitheatre, silverdome, mosfet, spaceflight, starred,
# Nearest to freedom: undersecretary, landslide, jutsu, clannad, laissez, opposed, sel, vows,
# Nearest to additional: calibrated, chording, rummel, unaided, elixir, saari, sardo, on,
# Nearest to professional: majors, departments, standards, organization, unscr, sukkah, consortium, classroom,
# Nearest to woman: nationality, vig, female, hiv, inhaled, prevalence, birth, fertility,
# Nearest to square: bosporus, sq, peninsulas, segment, provost, area, moldovans, metres,
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 38.9253 0.4032 sec/batch
# Nearest to see: all, cundinamarca, topics, concordance, globalsecurity, related, communications, history,
# Nearest to and: the, in, of, also, by, for, with, as,
# Nearest to all: be, see, in, armenia, are, the, satisfies, scsi,
# Nearest to if: aaliyah, nomar, surveyors, denoted, treenode, vectors, taz, f,
# Nearest to most: many, in, major, bodied, few, each, for, sets,
# Nearest to than: more, homozygote, least, bases, flanker, mightiest, rather, older,
# Nearest to war: vacancies, wounded, revisionist, propaganda, shrapnel, ratified, calonne, reich,
# Nearest to would: ran, finally, makkah, could, deterred, gully, continuance, had,
# Nearest to scale: tempered, devote, underemployed, methodology, slabs, flattening, ago, twelfth,
# Nearest to defense: tukey, cdg, picot, peacekeeping, backs, escorts, halakhah, assailants,
# Nearest to stage: maintainability, virtues, amphitheatre, starred, spaceflight, uefa, latitude, silverdome,
# Nearest to freedom: undersecretary, landslide, clannad, jutsu, laissez, opposed, bomber, sel,
# Nearest to additional: calibrated, chording, unaided, on, rummel, elixir, saari, pcb,
# Nearest to professional: majors, unscr, mahuad, standards, departments, sukkah, players, encamp,
# Nearest to woman: vig, nationality, female, hiv, prevalence, less, fertility, inhaled,
# Nearest to square: sq, bosporus, peninsulas, segment, provost, area, moldovans, stadt,
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 38.9542 0.4096 sec/batch
# Nearest to see: all, concordance, cundinamarca, related, topics, globalsecurity, of, terrier,
# Nearest to and: the, of, in, also, by, for, other, with,
# Nearest to all: be, in, see, are, the, armenia, satisfies, common,
# Nearest to if: denoted, aaliyah, vectors, treenode, f, it, multiplied, nomar,
# Nearest to most: many, in, bodied, major, each, few, both, enclaves,
# Nearest to than: more, least, homozygote, rather, flanker, xxxxx, mightiest, pride,
# Nearest to war: vacancies, ratified, wounded, revisionist, reich, midianites, shrapnel, propaganda,
# Nearest to would: ran, makkah, finally, gully, had, obstinately, wager, continuance,
# Nearest to scale: measuring, tempered, underemployed, devote, ago, imperceptible, methodology, flattening,
# Nearest to defense: tukey, cdg, peacekeeping, picot, backs, goal, passer, halakhah,
# Nearest to stage: maintainability, virtues, starred, latitude, amphitheatre, uefa, mosfet, spaceflight,
# Nearest to freedom: undersecretary, landslide, laissez, jutsu, clannad, vows, opposed, sel,
# Nearest to additional: calibrated, chording, on, unaided, rummel, elixir, saari, sardo,
# Nearest to professional: majors, unscr, standards, sukkah, departments, encamp, classroom, mahuad,
# Nearest to woman: vig, female, nationality, hiv, less, prevalence, birth, women,
# Nearest to square: sq, bosporus, segment, peninsulas, provost, contrasting, oblique, moldovans,
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 39.1219 0.4136 sec/batch
# Nearest to see: all, globalsecurity, related, topics, cundinamarca, history, concordance, external,
# Nearest to and: the, in, of, also, with, by, for, other,
# Nearest to all: be, see, in, are, armenia, the, common, any,
# Nearest to if: aaliyah, surveyors, denoted, it, nomar, treenode, vectors, same,
# Nearest to most: many, in, bodied, major, few, for, enclaves, each,
# Nearest to than: more, least, homozygote, mightiest, rather, less, xxxxx, bases,
# Nearest to war: vacancies, ratified, wounded, revisionist, shrapnel, nazi, reich, propaganda,
# Nearest to would: gully, ran, makkah, had, finally, zamenhof, wager, could,
# Nearest to scale: tempered, twelfth, measuring, underemployed, ago, tate, imperceptible, devote,
# Nearest to defense: tukey, cdg, peacekeeping, picot, halakhah, backs, goal, assailants,
# Nearest to stage: maintainability, virtues, amphitheatre, starred, omniscience, spaceflight, hbf, uefa,
# Nearest to freedom: undersecretary, landslide, laissez, jutsu, clannad, vows, entangled, bomber,
# Nearest to additional: chording, calibrated, on, unaided, rummel, sardo, saari, elixir,
# Nearest to professional: majors, standards, sukkah, unscr, departments, consortium, organization, encamp,
# Nearest to woman: female, less, hiv, vig, nationality, fertility, birth, prevalence,
# Nearest to square: sq, bosporus, segment, peninsulas, provost, moldovans, contrasting, basler,
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 39.0261 0.4107 sec/batch
# Nearest to see: all, topics, external, globalsecurity, cundinamarca, links, of, communications,
# Nearest to and: the, in, of, also, with, other, for, by,
# Nearest to all: be, see, in, are, the, armenia, any, does,
# Nearest to if: aaliyah, denoted, vectors, treenode, surveyors, same, f, nomar,
# ...
# Nearest to stage: maintainability, starred, virtues, silverdome, amphitheatre, latitude, capra, spaceflight,
# Nearest to freedom: undersecretary, jutsu, laissez, vows, internalism, landslide, websites, entangled,
# Nearest to additional: on, calibrated, chording, unaided, sardo, rummel, other, fullback,
# Nearest to professional: majors, standards, sukkah, players, wrestler, unscr, organization, reedy,
# Nearest to woman: vig, female, hiv, flattering, women, fertility, nationality, heliport,
# Nearest to square: segment, sq, provost, bosporus, isp, peninsulas, kj, svg,
# Epoch 8/10 Iteration: 36000 Avg. Training loss: 38.8257 0.4108 sec/batch
# Nearest to see: all, links, external, globalsecurity, topics, of, related, history,
# Nearest to and: the, in, of, for, with, also, s, as,
# Nearest to all: be, are, see, in, armenia, scsi, does, any,
# Nearest to if: surveyors, it, vectors, aaliyah, land, denoted, multiplied, f,
# Nearest to most: many, in, are, each, other, for, bodied, few,
# Nearest to than: more, least, homozygote, less, mightiest, older, much, rather,
# Nearest to war: ratified, vacancies, wounded, fought, revisionist, airlift, surrender, nathaniel,
# Nearest to would: had, ran, could, gully, zamenhof, continuance, obstinately, barak,
# Nearest to scale: tempered, tate, underemployed, accommodate, twelfth, slabs, devote, ago,
# Nearest to defense: cdg, tukey, halakhah, peacekeeping, passer, backs, agnew, assailants,
# Nearest to stage: starred, maintainability, silverdome, amphitheatre, capra, virtues, intruder, manzarek,
# Nearest to freedom: undersecretary, jutsu, laissez, landslide, vows, lom, internalism, clannad,
# Nearest to additional: calibrated, on, chording, sardo, rummel, other, unaided, saari,
# Nearest to professional: majors, standards, wrestler, sukkah, encamp, moniker, sibelius, players,
# Nearest to woman: vig, female, hiv, fertility, nationality, less, flattering, women,
# Nearest to square: sq, segment, provost, bosporus, moldovans, peninsulas, isp, metres,
# Epoch 8/10 Iteration: 37000 Avg. Training loss: 38.8073 0.4053 sec/batch
# Nearest to see: all, links, external, topics, of, globalsecurity, has, related,
# Nearest to and: the, in, also, with, for, of, as, a,
# Nearest to all: be, are, see, in, armenia, the, any, scsi,
# Nearest to if: surveyors, vectors, f, aaliyah, multiplied, treenode, nomar, same,
# Nearest to most: many, in, for, major, each, few, are, other,
# Nearest to than: more, least, homozygote, less, much, mightiest, rather, older,
# Nearest to war: vacancies, ratified, revisionist, wounded, reich, submarines, fought, sanctified,
# Nearest to would: had, could, gully, ran, continuance, barak, zamenhof, obstinately,
# Nearest to scale: tempered, tate, progressions, twelfth, underemployed, measuring, accommodate, slabs,
# Nearest to defense: cdg, tukey, halakhah, peacekeeping, passer, goal, assailants, agnew,
# Nearest to stage: maintainability, starred, silverdome, theatre, performances, intruder, manzarek, capra,
# Nearest to freedom: undersecretary, jutsu, laissez, landslide, internalism, vows, eccentricity, lom,
# Nearest to additional: calibrated, on, chording, sardo, rummel, other, a, tabular,
# Nearest to professional: majors, standards, wrestler, sukkah, unscr, moniker, encamp, goshen,
# Nearest to woman: hiv, female, vig, fertility, nationality, birth, heliport, prevalence,
# Nearest to square: sq, provost, bosporus, segment, peninsulas, metres, moldovans, callixtus,
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 38.5297 0.4053 sec/batch
# Nearest to see: all, links, external, globalsecurity, and, of, topics, concordance,
# Nearest to and: the, in, also, of, as, a, with, for,
# Nearest to all: are, be, see, in, the, any, this, armenia,
# Nearest to if: surveyors, aaliyah, vectors, multiplied, should, f, land, that,
# Nearest to most: many, in, for, major, few, each, are, bodied,
# Nearest to than: more, least, homozygote, less, much, rather, mightiest, payloads,
# Nearest to war: vacancies, ratified, wounded, revisionist, fought, surrender, weapons, shrapnel,
# Nearest to would: had, could, gully, ran, barak, continuance, to, zamenhof,
# Nearest to scale: tempered, tate, underemployed, progressions, twelfth, measuring, accommodate, slabs,
# Nearest to defense: cdg, tukey, passer, defensive, backs, assailants, peacekeeping, goal,
# Nearest to stage: maintainability, starred, manzarek, performances, silverdome, kalinin, intruder, capra,
# Nearest to freedom: undersecretary, vows, jutsu, laissez, landslide, internalism, eccentricity, lom,
# Nearest to additional: on, calibrated, other, chording, elixir, rummel, sardo, a,
# Nearest to professional: majors, wrestler, standards, players, sukkah, encamp, goshen, unscr,
# Nearest to woman: female, hiv, vig, fertility, nationality, birth, heliport, flattering,
# Nearest to square: sq, provost, metres, bosporus, segment, callixtus, basler, acre,
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 38.3667 0.4044 sec/batch
# Nearest to see: all, links, of, and, related, external, concordance, has,
# Nearest to and: the, in, also, for, of, a, with, as,
# Nearest to all: be, are, in, see, any, the, this, a,
# Nearest to if: surveyors, it, f, aaliyah, land, vectors, same, be,
# Nearest to most: many, in, for, are, both, each, major, have,
# Nearest to than: more, least, homozygote, less, rather, much, advantages, spades,
# Nearest to war: ratified, vacancies, wounded, weapons, revisionist, surrender, dips, nathaniel,
# Nearest to would: had, gully, finally, wager, ran, could, continuance, have,
# Nearest to scale: tempered, tate, progressions, measuring, underemployed, twelfth, scrambling, accommodate,
# Nearest to defense: cdg, tukey, defensive, passer, goal, peacekeeping, halakhah, backs,
# Nearest to stage: starred, maintainability, silverdome, manzarek, intruder, kalinin, performances, theatre,
# Nearest to freedom: undersecretary, internalism, vows, laissez, landslide, jutsu, entangled, lom,
# Nearest to additional: on, other, calibrated, chording, elixir, a, fullback, rummel,
# Nearest to professional: majors, standards, wrestler, sukkah, encamp, unscr, departments, moniker,
# Nearest to woman: hiv, female, vig, fertility, nationality, flattering, less, birth,
# Nearest to square: segment, sq, provost, metres, bosporus, units, kj, basler,
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 38.5904 0.4084 sec/batch
# Nearest to see: all, links, and, external, has, topics, of, globalsecurity,
# Nearest to and: the, of, in, also, for, by, a, with,
# Nearest to all: be, are, in, see, any, this, the, armenia,
# Nearest to if: surveyors, it, be, same, aaliyah, treenode, vectors, multiplied,
# Nearest to most: many, in, are, for, major, few, both, other,
# Nearest to than: more, least, less, homozygote, much, rather, contribute, advantages,
# Nearest to war: ratified, vacancies, surrender, revisionist, fought, allies, nathaniel, wounded,
# Nearest to would: had, gully, continuance, obstinately, zamenhof, wager, ran, endorse,
# Nearest to scale: tempered, underemployed, tate, measuring, progressions, ago, devote, scrambling,
# Nearest to defense: cdg, tukey, halakhah, defensive, passer, assailants, peacekeeping, pont,
# Nearest to stage: starred, maintainability, theatre, performances, silverdome, capra, intruder, manzarek,
# Nearest to freedom: undersecretary, laissez, vows, internalism, jutsu, lom, entangled, naacp,
# Nearest to additional: on, other, calibrated, chandeliers, sardo, chording, fullback, some,
# Nearest to professional: majors, standards, wrestler, sukkah, moniker, unscr, encamp, goshen,
# Nearest to woman: female, hiv, fertility, vig, nationality, birth, flattering, women,
# Nearest to square: segment, sq, provost, metres, units, svg, flags, bosporus,
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 38.6572 0.4285 sec/batch
# Nearest to see: all, links, external, topics, globalsecurity, of, three, related,
# Nearest to and: the, in, also, with, of, a, for, as,
# Nearest to all: are, be, see, in, any, the, armenia, this,
# Nearest to if: surveyors, it, conceals, land, aaliyah, be, not, multiplied,
# Nearest to most: many, in, are, for, few, mostly, major, have,
# Nearest to than: more, less, homozygote, least, much, rather, advantages, contribute,
# Nearest to war: wounded, vacancies, weapons, ratified, revisionist, fought, nathaniel, surrender,
# Nearest to would: had, continuance, gully, have, could, zamenhof, obstinately, finally,
# Nearest to scale: tempered, tate, underemployed, progressions, tuning, twelfth, measuring, scrambling,
# Nearest to defense: cdg, tukey, halakhah, peacekeeping, goal, defensive, benefitting, assailants,
# Nearest to stage: starred, maintainability, theatre, kalinin, performances, manzarek, intruder, silverdome,
# Nearest to freedom: laissez, internalism, undersecretary, vows, lom, individual, naacp, entangled,
# Nearest to additional: on, other, a, chandeliers, sardo, some, calibrated, fullback,
# Nearest to professional: majors, wrestler, moniker, standards, sukkah, encamp, goshen, unscr,
# Nearest to woman: female, hiv, fertility, vig, nationality, birth, women, flattering,
# Nearest to square: sq, segment, provost, metres, units, bosporus, callixtus, svg,
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 38.3664 0.1480 sec/batch
# Nearest to see: all, links, external, of, three, and, topics, globalsecurity,
# Nearest to and: the, in, of, with, also, as, by, a,
# Nearest to all: are, be, see, in, any, the, armenia, this,
# Nearest to if: surveyors, be, conceals, it, same, aaliyah, land, multiplied,
# Nearest to most: many, in, are, both, major, few, have, for,
# Nearest to than: more, less, homozygote, least, much, rather, advantages, payloads,
# Nearest to war: wounded, ratified, vacancies, revisionist, surrender, nathaniel, fought, reconquered,
# Nearest to would: had, could, obstinately, gully, to, barak, was, continuance,
# Nearest to scale: tempered, tuning, tate, underemployed, progressions, twelfth, measuring, ago,
# Nearest to defense: cdg, tukey, goal, backs, passer, defensive, halakhah, benefitting,
# Nearest to stage: starred, maintainability, theatre, kalinin, manzarek, intruder, silverdome, start,
# Nearest to freedom: vows, laissez, internalism, eccentricity, undersecretary, sel, lom, entangled,
# Nearest to additional: on, other, a, chording, calibrated, fullback, sardo, elixir,
# Nearest to professional: majors, wrestler, standards, moniker, sukkah, goshen, classroom, sibelius,
# Nearest to woman: female, hiv, nationality, vig, fertility, flattering, heliport, women,
# Nearest to square: metres, sq, provost, units, segment, callixtus, bosporus, area,
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 38.1919 0.4033 sec/batch
# Nearest to see: all, links, of, external, and, or, also, three,
# Nearest to and: in, the, also, of, with, by, as, for,
# Nearest to all: are, be, in, see, any, the, this, there,
# Nearest to if: be, surveyors, same, treenode, f, can, should, conceals,
# Nearest to most: many, in, are, for, other, major, become, have,
# Nearest to than: more, less, least, much, homozygote, rather, advantages, has,
# Nearest to war: ratified, wounded, vacancies, commanders, weapons, revisionist, fought, reconquered,
# Nearest to would: had, could, to, continuance, gully, barak, have, obstinately,
# Nearest to scale: tempered, progressions, tate, tuning, twelfth, underemployed, ago, measuring,
# Nearest to defense: cdg, tukey, flathead, passer, peacekeeping, armed, benefitting, goal,
# Nearest to stage: starred, maintainability, start, manzarek, theatre, performances, capra, kalinin,
# Nearest to freedom: vows, internalism, laissez, eccentricity, undersecretary, lom, sel, naacp,
# Nearest to additional: on, other, a, elixir, some, by, chording, sardo,
# Nearest to professional: majors, wrestler, standards, armaments, players, moniker, disciplines, sukkah,
# Nearest to woman: hiv, female, vig, fertility, nationality, flattering, heliport, women,
# Nearest to square: sq, metres, provost, units, segment, svg, callixtus, acre,
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 38.2717 0.4126 sec/batch
# Nearest to see: of, all, links, and, external, a, three, or,
# Nearest to and: the, in, of, also, with, for, a, as,
# Nearest to all: are, in, be, see, any, the, and, common,
# Nearest to if: be, it, surveyors, treenode, land, same, denoted, conceals,
# Nearest to most: many, in, are, for, have, both, few, major,
# Nearest to than: more, much, less, rather, least, homozygote, advantages, but,
# Nearest to war: ratified, vacancies, wounded, commanders, nathaniel, revisionist, reconquered, surrender,
# Nearest to would: had, to, wager, have, could, gully, continuance, was,
# Nearest to scale: tempered, tate, tuning, progressions, underemployed, measuring, ago, twelfth,
# Nearest to defense: cdg, tukey, goal, flathead, halakhah, passer, peacekeeping, armed,
# Nearest to stage: starred, maintainability, theatre, intruder, start, kalinin, manzarek, performances,
# Nearest to freedom: internalism, vows, eccentricity, undersecretary, laissez, naacp, lom, entangled,
# Nearest to additional: on, other, a, chording, elixir, fullback, some, calibrated,
# Nearest to professional: majors, wrestler, standards, classroom, moniker, armaments, sukkah, disciplines,
# Nearest to woman: hiv, female, vig, nationality, fertility, flattering, heliport, women,
# Nearest to square: provost, sq, metres, segment, svg, units, callixtus, kj,
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 38.3799 0.4083 sec/batch
# Nearest to see: of, links, all, external, and, three, a, history,
# Nearest to and: the, in, of, with, also, for, by, as,
# Nearest to all: are, be, see, in, any, and, the, some,
# Nearest to if: be, surveyors, it, land, treenode, conceals, same, that,
# Nearest to most: many, in, are, for, mostly, become, have, major,
# Nearest to than: more, much, less, least, rather, homozygote, has, but,
# Nearest to war: vacancies, ratified, commanders, weapons, reconquered, wounded, occupation, fought,
# Nearest to would: had, to, could, have, gully, continuance, for, wager,
# Nearest to scale: tempered, tuning, twelfth, tate, underemployed, accommodate, progressions, ago,
# Nearest to defense: cdg, tukey, halakhah, flathead, goal, benefitting, peacekeeping, passer,
# Nearest to stage: starred, maintainability, intruder, theatre, start, manzarek, omniscience, cytokinesis,
# Nearest to freedom: vows, laissez, jutsu, internalism, ind, individual, eccentricity, naacp,
# Nearest to additional: other, on, fullback, some, a, few, chording, the,
# Nearest to professional: majors, wrestler, standards, sukkah, moniker, tunneling, goshen, players,
# Nearest to woman: female, hiv, fertility, nationality, flattering, birth, vig, women,
# Nearest to square: provost, sq, segment, metres, svg, callixtus, units, kj,
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 38.4266 0.4092 sec/batch
# Nearest to see: of, all, links, external, and, also, topics, or,
# Nearest to and: the, in, of, with, also, as, for, by,
# Nearest to all: are, be, see, in, the, there, any, and,
# Nearest to if: be, surveyors, it, not, land, can, same, treenode,
# Nearest to most: many, in, are, for, become, few, mostly, have,
# Nearest to than: more, less, much, homozygote, least, rather, advantages, has,
# Nearest to war: vacancies, ratified, wounded, ii, weapons, surrender, revisionist, sanctified,
# Nearest to would: to, have, had, could, gully, was, continuance, zamenhof,
# Nearest to scale: tempered, progressions, tuning, underemployed, tate, accommodate, ago, twelfth,
# Nearest to defense: cdg, tukey, halakhah, goal, peacekeeping, flathead, armed, availability,
# Nearest to stage: starred, theatre, maintainability, intruder, kalinin, manzarek, latitude, performances,
# Nearest to freedom: laissez, vows, internalism, naacp, eccentricity, jutsu, freedoms, lom,
# Nearest to additional: other, on, fullback, a, chording, few, some, elixir,
# Nearest to professional: wrestler, majors, moniker, sukkah, goshen, standards, tunneling, sibelius,
# Nearest to woman: female, hiv, nationality, fertility, born, birth, women, adjective,
# Nearest to square: sq, provost, segment, callixtus, units, metres, svg, acre,

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
plt.xlim((-5,8))
plt.ylim((-7,5))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
