# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
words[:50]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_words[:20]
# Out:
# [5233,
#  3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-05
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word,count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

train_words = [word for word in int_words if random.random() < (1-p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1,window_size+1)
    start = idx - R if (idx-R)>0 else 0
    stop = idx+R
    result = set(words[start:idx] + words[idx+1:stop+1])
    return list(result)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name='inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=n_vocab**-0.5))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,
                                     labels,embed,
                                     n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From D:\SoftWare\Anaconda3\envs\pyDL\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-14-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# 子目录或文件 checkpoints 已经存在。

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 2000 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 4000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 98.9795 0.3201 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 91.8800 0.3184 sec/batch
# Nearest to this: hypotheses, myself, canso, observations, hangers, tutorials, vivian, sharps,
# Nearest to other: tsing, trading, sayfawa, dialogue, osha, nh, transclusion, according,
# Nearest to many: switcher, sneak, lihou, warding, epidemiological, aramean, wreath, savvy,
# Nearest to its: endless, singaporean, vegan, traumatic, episcopalians, redevelop, also, streamlined,
# Nearest to s: wapping, overtly, alpher, centaur, codings, sicherheitsdienst, rachael, reflected,
# Nearest to three: coco, lai, aba, sunflower, genomes, births, statesman, edifice,
# Nearest to of: oklahoma, infraction, privileges, mixtec, tractates, michinaga, modern, advice,
# Nearest to four: ft, contractive, hughie, directors, knighted, grossing, carroll, wanna,
# Nearest to egypt: arab, aristarchus, stoic, electoral, wilderness, toughest, zander, hogarth,
# Nearest to applications: mychal, spawning, intensity, marva, azimuth, use, twenties, distribution,
# Nearest to bill: voortrekker, omelette, plunkett, brooker, prevailed, bonfire, garde, sachsenhausen,
# Nearest to hit: shorthair, colonizers, recalls, forgetting, silicates, siouxsie, rochelle, nada,
# Nearest to experience: cull, enneads, romanticized, bandar, vinge, here, apricot, malcha,
# Nearest to alternative: divers, folktales, coria, sultans, relates, cleves, dimensional, wherever,
# Nearest to square: dwindling, yearbook, thinner, mesoamerica, artistry, attainment, heartless, grisly,
# Nearest to numerous: financial, strategic, pads, renewal, celebrate, sicilia, intron, lavender,
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 87.9957 0.2185 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 86.0022 0.3179 sec/batch
# Nearest to this: myself, canso, suprarenal, hypotheses, tutorials, culprit, hangers, autistics,
# Nearest to other: tsing, dialogue, sayfawa, osha, trading, transclusion, pronouncement, obstacles,
# Nearest to many: switcher, llah, warding, lihou, wreath, combative, epidemiological, trademarks,
# Nearest to its: singaporean, also, endless, episcopalians, traumatic, retirements, decline, sia,
# Nearest to s: wapping, overtly, centaur, epilogue, alpher, roving, hairpin, ascanio,
# Nearest to three: lai, genomes, combinatorial, usmc, coco, pbx, zamboanga, frs,
# Nearest to of: infraction, oklahoma, privileges, modern, connectives, steam, michinaga, precipitate,
# Nearest to four: governed, lviv, ft, sysop, grossing, contractive, wanna, restructured,
# Nearest to egypt: arab, stoic, khorasan, aristarchus, zander, jammu, ibn, methodius,
# Nearest to applications: page, spawning, rasa, azimuth, desk, distribution, mychal, twenties,
# Nearest to bill: voortrekker, brooker, omelette, sachsenhausen, bush, oscars, petherbridge, prevailed,
# Nearest to hit: shorthair, forgetting, recalls, rochelle, siouxsie, colonizers, silicates, nada,
# Nearest to experience: cull, romanticized, ll, bandar, enneads, malcha, apricot, vinge,
# Nearest to alternative: coria, divers, distortion, mun, kanton, mos, complete, wherever,
# Nearest to square: yearbook, dwindling, thinner, mesoamerica, artistry, heartless, grisly, tard,
# Nearest to numerous: lavender, celebrate, toponymy, financial, renewal, pads, ichij, coordinators,
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 84.4235 0.1190 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 83.1235 0.3197 sec/batch
# Nearest to this: adaption, myself, suprarenal, culprit, flea, tutorials, outdated, autistics,
# Nearest to other: dialogue, tsing, pronouncement, osha, sayfawa, detergents, transclusion, obstacles,
# Nearest to many: llah, switcher, warding, combative, savvy, wreath, aramean, epidemiological,
# Nearest to its: also, singaporean, endless, streamlined, decline, retirements, traumatic, curiae,
# Nearest to s: wapping, overtly, epilogue, centaur, alpher, reflected, hairpin, rachael,
# Nearest to three: lai, genomes, frs, pbx, usmc, isaf, maintainability, combinatorial,
# Nearest to of: infraction, oklahoma, connectives, michinaga, precipitate, augustinian, bohm, steam,
# Nearest to four: governed, sysop, lviv, macross, ft, restructured, waite, hughie,
# Nearest to egypt: stoic, arab, khorasan, jammu, embolism, mahuad, pseudepigraphical, cardini,
# Nearest to applications: spawning, gec, kde, deleted, azimuth, page, desk, distribution,
# Nearest to bill: voortrekker, brooker, oscars, bush, omelette, sachsenhausen, petherbridge, unwanted,
# Nearest to hit: shorthair, forgetting, recalls, rochelle, colonizers, silicates, nada, siouxsie,
# Nearest to experience: bandar, enneads, cull, ll, unnatural, vinge, romanticized, vanishing,
# Nearest to alternative: coria, distortion, mun, divers, kanton, complete, measures, mos,
# Nearest to square: dwindling, yearbook, thinner, artistry, mesoamerica, tard, heartless, arabah,
# Nearest to numerous: lavender, celebrate, financial, coordinators, deviance, toponymy, renewal, intron,
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 82.6967 0.0198 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 81.2086 0.3174 sec/batch
# Nearest to this: adaption, reinvention, lemelson, autistics, gilt, tutorials, voris, suprarenal,
# Nearest to other: dialogue, tsing, osha, pronouncement, detergents, sayfawa, transclusion, trading,
# Nearest to many: llah, switcher, savvy, trademarks, warding, sneak, combative, permeation,
# Nearest to its: also, endless, singaporean, decline, streamlined, infinitude, curiae, gravitons,
# Nearest to s: wapping, epilogue, overtly, centaur, reflected, alpher, hairpin, namely,
# Nearest to three: genomes, pbx, encoder, lai, frs, conferencing, combinatorial, johnnie,
# Nearest to of: infraction, connectives, michinaga, bohm, augustinian, oklahoma, peppered, hydrozoa,
# Nearest to four: governed, household, sysop, macross, lviv, ft, harel, tata,
# Nearest to egypt: stoic, arab, mahuad, beacon, pseudepigraphical, khorasan, historiography, cardini,
# Nearest to applications: gec, informatics, spawning, bootstrapping, overriding, desk, wendover, deleted,
# Nearest to bill: voortrekker, oscars, brooker, petherbridge, omelette, bush, sachsenhausen, marketers,
# Nearest to hit: shorthair, forgetting, recalls, rochelle, umpires, siouxsie, nada, faults,
# Nearest to experience: enneads, vinge, kicked, vanishing, bandar, unnatural, ll, disparate,
# Nearest to alternative: coria, distortion, mun, kanton, thermometers, divers, complete, mos,
# Nearest to square: dwindling, yearbook, thinner, arabah, tard, aswan, southampton, equidistant,
# Nearest to numerous: lavender, celebrate, toponymy, financial, coordinators, deviance, crossword, intron,
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 81.3684 0.3189 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 80.1343 0.2376 sec/batch
# Nearest to this: adaption, gilt, autistics, voris, suprarenal, reinvention, lemelson, gratitude,
# Nearest to other: tsing, dialogue, osha, detergents, transclusion, pronouncement, sayfawa, assorted,
# Nearest to many: llah, savvy, switcher, nutritionally, trademarks, permeation, warding, sneak,
# Nearest to its: also, singaporean, endless, decline, streamlined, curiae, porvoo, ould,
# Nearest to s: wapping, overtly, epilogue, reflected, hairpin, centaur, boardwalk, namely,
# Nearest to three: pbx, encoder, genomes, two, lai, four, frs, kingman,
# Nearest to of: infraction, michinaga, connectives, hydrozoa, augustinian, angus, pamir, stereo,
# Nearest to four: governed, three, household, lviv, macross, purchasing, sysop, tata,
# Nearest to egypt: stoic, beacon, pseudepigraphical, mahuad, historiography, cardini, propulsion, arab,
# Nearest to applications: gec, informatics, bootstrapping, desk, aelianus, rejecting, wdc, wendover,
# Nearest to bill: voortrekker, oscars, brooker, petherbridge, marketers, omelette, bush, guessed,
# Nearest to hit: shorthair, forgetting, umpires, recalls, faults, lasorda, rochelle, avril,
# Nearest to experience: enneads, kicked, vanishing, vinge, bandar, corelli, disparate, cull,
# Nearest to alternative: coria, mun, distortion, kanton, sultans, complete, thermometers, mos,
# Nearest to square: yearbook, dwindling, arabah, thinner, grisly, attainment, aswan, tard,
# Nearest to numerous: lavender, toponymy, financial, celebrate, impressionist, intron, deviance, crossword,
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 80.1555 0.3167 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 79.8780 0.1386 sec/batch
# Nearest to this: adaption, voris, reinvention, lemelson, culprit, portus, gilt, outdated,
# Nearest to other: tsing, dialogue, detergents, osha, pronouncement, assorted, anubis, transclusion,
# Nearest to many: llah, trademarks, nutritionally, switcher, savvy, warding, chemically, sneak,
# Nearest to its: also, singaporean, endless, decline, streamlined, curiae, porvoo, kimberlite,
# Nearest to s: wapping, epilogue, overtly, centaur, reflected, alpher, namely, boardwalk,
# Nearest to three: two, pbx, four, encoder, lai, genomes, kingman, frs,
# Nearest to of: michinaga, augustinian, infraction, hydrozoa, angus, connectives, allene, prayers,
# Nearest to four: three, macross, household, nine, syngman, tata, purchasing, segregationist,
# Nearest to egypt: stoic, pseudepigraphical, beacon, propulsion, cardini, historiography, arab, gamal,
# Nearest to applications: gec, informatics, wdc, rejecting, desk, enriching, resourceful, diagnosis,
# Nearest to bill: voortrekker, oscars, marketers, brooker, bush, chileans, baraka, guessed,
# Nearest to hit: shorthair, forgetting, recalls, lasorda, faults, umpires, idols, bogart,
# Nearest to experience: enneads, vanishing, pbr, kicked, interacts, corelli, infirmary, vinge,
# Nearest to alternative: coria, mun, distortion, kanton, sultans, thermometers, colophon, complete,
# Nearest to square: yearbook, arabah, dwindling, thinner, attainment, ineligible, aswan, axl,
# Nearest to numerous: lavender, toponymy, impressionist, financial, intron, crossword, deviance, attractions,
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 79.3514 0.3200 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 79.2781 0.0390 sec/batch
# Nearest to this: adaption, voris, reinvention, portus, gratitude, lemelson, cistercians, gilt,
# Nearest to other: tsing, assorted, anubis, quote, detergents, pronouncement, transclusion, osha,
# Nearest to many: trademarks, llah, savvy, sneak, permeation, nutritionally, switcher, gloster,
# Nearest to its: also, endless, singaporean, curiae, porvoo, streamlined, decline, kimberlite,
# Nearest to s: wapping, reflected, overtly, centaur, epilogue, put, boardwalk, alles,
# Nearest to three: two, four, pbx, lai, encoder, pallium, seven, finch,
# Nearest to of: michinaga, pamir, connectives, and, augustinian, chessboard, hydrozoa, allene,
# Nearest to four: three, nine, macross, household, seven, syngman, purchasing, tata,
# Nearest to egypt: stoic, pseudepigraphical, beacon, historiography, cardini, educated, gamal, embolism,
# Nearest to applications: gec, wdc, resourceful, overriding, desk, diagnosis, rejecting, wendover,
# Nearest to bill: voortrekker, oscars, marketers, brooker, chileans, baraka, guessed, petherbridge,
# Nearest to hit: recalls, shorthair, lasorda, forgetting, faults, idols, colonizers, bystanders,
# Nearest to experience: enneads, interacts, vanishing, pbr, infirmary, corelli, kicked, vinge,
# Nearest to alternative: coria, kanton, mun, distortion, sultans, thermometers, colophon, complete,
# Nearest to square: yearbook, arabah, dwindling, ineligible, attainment, cvbgs, axl, franck,
# Nearest to numerous: lavender, toponymy, impressionist, financial, intron, reassert, deviance, mayol,
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 78.6345 0.3176 sec/batch
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 78.8278 0.3227 sec/batch
# Nearest to this: adaption, portus, spool, lemelson, reinvention, voris, fame, away,
# Nearest to other: assorted, tsing, detergents, quote, anubis, styles, transclusion, pronouncement,
# Nearest to many: llah, trademarks, chemically, ukrainians, agree, savvy, permeation, sneak,
# Nearest to its: also, endless, curiae, singaporean, porvoo, decline, almost, traumatic,
# Nearest to s: wapping, with, put, alles, overtly, epilogue, boardwalk, mbox,
# Nearest to three: two, four, seven, pbx, presently, encoder, years, one,
# Nearest to of: and, michinaga, the, one, pamir, hydrozoa, with, lunations,
# Nearest to four: three, nine, seven, household, six, macross, purchasing, years,
# Nearest to egypt: stoic, pseudepigraphical, cardini, beacon, historiography, educated, propulsion, auchinleck,
# Nearest to applications: gec, wdc, diagnosis, regent, intensity, nos, overriding, enriching,
# Nearest to bill: voortrekker, marketers, brooker, oscars, chileans, baraka, vetoes, fine,
# Nearest to hit: recalls, lasorda, shorthair, forgetting, faults, idols, pepe, rochelle,
# Nearest to experience: enneads, interacts, pbr, infirmary, vanishing, corelli, fifteen, ahern,
# Nearest to alternative: coria, kanton, mun, sultans, distortion, complete, colophon, eurasia,
# Nearest to square: arabah, yearbook, attainment, ineligible, dwindling, axl, cvbgs, franck,
# Nearest to numerous: lavender, financial, impressionist, mayol, toponymy, intron, coordinators, nurseries,
# Epoch 8/10 Iteration: 34000 Avg. Training loss: 78.1725 0.2571 sec/batch
# Epoch 8/10 Iteration: 36000 Avg. Training loss: 78.2281 0.3135 sec/batch
# Nearest to this: adaption, portus, prime, away, spool, reinvention, voris, gratitude,
# Nearest to other: assorted, quote, anubis, pronouncement, tsing, side, series, styles,
# Nearest to many: llah, trademarks, agree, nation, sneak, permeation, ukrainians, chemically,
# Nearest to its: also, endless, curiae, singaporean, porvoo, almost, streamlined, decline,
# Nearest to s: with, put, wapping, three, duesberg, epilogue, alles, the,
# Nearest to three: four, two, one, seven, nine, zero, five, pbx,
# Nearest to of: the, and, one, michinaga, with, eight, hydrozoa, modern,
# Nearest to four: three, nine, six, seven, one, macross, two, zero,
# Nearest to egypt: stoic, pseudepigraphical, educated, historiography, gamal, auchinleck, eligibility, beacon,
# Nearest to applications: gec, wdc, intensity, diagnosis, perkins, regent, overriding, desk,
# Nearest to bill: voortrekker, marketers, vetoes, brooker, fine, oscars, baraka, chileans,
# Nearest to hit: lasorda, recalls, forgetting, shorthair, faults, gamsakhurdia, idols, bogart,
# Nearest to experience: interacts, infirmary, pbr, enneads, vanishing, ahern, corelli, here,
# Nearest to alternative: coria, kanton, mun, distortion, colophon, sultans, complete, spongiform,
# Nearest to square: attainment, arabah, yearbook, cvbgs, ineligible, franck, dwindling, axl,
# Nearest to numerous: lavender, financial, toponymy, intron, impressionist, nurseries, mayol, deviance,
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 78.0499 0.1561 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 77.7125 0.3145 sec/batch
# Nearest to this: adaption, away, voris, spool, schwenkfeld, prime, cistercians, reinvention,
# Nearest to other: assorted, quote, anubis, side, styles, layout, series, grand,
# Nearest to many: agree, llah, trademarks, undoubtedly, antiquaries, ukrainians, nation, permeation,
# Nearest to its: also, endless, curiae, singaporean, the, streamlined, porvoo, almost,
# Nearest to s: with, three, put, the, alles, namely, wapping, nine,
# Nearest to three: four, two, one, seven, nine, zero, years, pbx,
# Nearest to of: the, and, one, with, michinaga, most, modern, hydrozoa,
# Nearest to four: three, six, seven, nine, one, two, years, zero,
# Nearest to egypt: pseudepigraphical, stoic, educated, historiography, gamal, beacon, eligibility, propulsion,
# Nearest to applications: gec, intensity, wdc, diagnosis, regent, nematic, nanoscale, wendover,
# Nearest to bill: voortrekker, marketers, vetoes, brooker, fine, chileans, oscars, baraka,
# Nearest to hit: lasorda, recalls, forgetting, idols, faults, gamsakhurdia, parodied, shorthair,
# Nearest to experience: interacts, pbr, enneads, infirmary, ahern, vanishing, here, disclosures,
# Nearest to alternative: coria, mun, kanton, colophon, distortion, sultans, complete, languished,
# Nearest to square: cvbgs, arabah, ineligible, attainment, yearbook, axl, franck, dwindling,
# Nearest to numerous: lavender, toponymy, financial, mayol, impressionist, nurseries, reclaimed, heretical,
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 77.8475 0.0577 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 77.1868 0.3145 sec/batch
# Nearest to this: adaption, spool, a, to, the, portus, lemelson, voris,
# Nearest to other: assorted, quote, anubis, side, according, styles, layout, are,
# Nearest to many: trademarks, llah, agree, undoubtedly, antiquaries, ukrainians, chemically, nation,
# Nearest to its: also, endless, curiae, the, porvoo, almost, singaporean, streamlined,
# Nearest to s: with, the, three, nine, put, and, r, alles,
# Nearest to three: four, two, one, seven, nine, zero, five, six,
# Nearest to of: the, and, one, with, most, in, as, on,
# Nearest to four: three, six, seven, one, nine, zero, two, five,
# Nearest to egypt: stoic, pseudepigraphical, educated, eligibility, historiography, gamal, osman, cardini,
# Nearest to applications: gec, intensity, diagnosis, regent, nematic, ides, danorum, nos,
# Nearest to bill: voortrekker, marketers, brooker, baraka, fine, vetoes, guessed, yin,
# Nearest to hit: lasorda, hits, idols, recalls, parodied, gamsakhurdia, forgetting, faults,
# Nearest to experience: interacts, pbr, enneads, infirmary, corelli, disclosures, unnatural, instants,
# Nearest to alternative: mun, coria, kanton, colophon, distortion, spongiform, ize, sultans,
# Nearest to square: ineligible, cvbgs, arabah, attainment, axl, aswan, yearbook, lies,
# Nearest to numerous: lavender, toponymy, financial, mayol, nurseries, deviance, impressionist, reassert,
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 77.6138 0.3122 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
